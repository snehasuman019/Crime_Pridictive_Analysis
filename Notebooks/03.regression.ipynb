# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# LinearRegression → Simple & Multiple LR
# PolynomialFeatures → Polynomial Regression
# LogisticRegression → Logistic Regression
# Metrics → MAE, MSE, RMSE, R²

# %%
df = pd.read_csv(("C:\\Users\\Sneha\\Desktop\\Crime Pridictive Analysis\\data\\crime_preprocessed.csv"),encoding = "Latin 1")
df.head()
# Out:
#        Ã¯Â»Â¿X            Y       CCN                 REPORT_DAT  \
# 0  400588.4650  129470.0424   5131706  2025-02-05 05:00:00+00:00
# 1  399950.1386  130512.4788  17194618  2025-06-30 04:00:00+00:00
# 2  406827.3300  136094.5500  22058767  2025-06-30 04:00:00+00:00
# 3  399075.7100  128801.5400  22108667  2025-01-02 05:00:00+00:00
# 4  396953.5100  146888.4100  25102388  2025-07-08 00:50:25+00:00
#
#                START_DATE                END_DATE  \
# 0  2005/09/27 07:25:00+00  2005/09/27 07:26:00+00
# 1  2017/11/09 20:44:00+00  2017/11/09 22:57:34+00
# 2  2022/04/28 02:21:00+00  2022/04/28 05:00:00+00
# 3  2022/07/30 01:12:00+00  2022/07/30 01:13:00+00
# 4  2025/07/07 11:00:00+00  2025/07/07 16:00:00+00
#
#                                    BLOCK  OFFENSE  METHOD  SHIFT  ...  BID  \
# 0     800 - 899 BLOCK OF XENIA STREET SE        3       0      2  ...  NaN
# 1     3200 - 3299 BLOCK OF 4TH STREET SE        3       0      2  ...  NaN
# ...

# %%
X = df[['Year', 'Month', 'LATITUDE', 'LONGITUDE']]
y = df['Hour']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R²:", r2)
# Out:
# MAE: 0.854517506108403
# MSE: 0.991541881497918
# RMSE: 0.9957619602585339
# R²: 0.007657655139577835

# %%
# Polynomial Regression
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)
X_train_p, X_test_p, y_train_p, y_test_p = train_test_split(
    X_poly, y, test_size=0.25, random_state=42
)

# %%
poly_lr = LinearRegression()
poly_lr.fit(X_train_p, y_train_p)
# Out:
# LinearRegression()

# %%
y_poly_pred = poly_lr.predict(X_test_p)

rmse_poly = np.sqrt(mean_squared_error(y_test_p, y_poly_pred))
r2_poly = r2_score(y_test_p, y_poly_pred)

print("Polynomial RMSE:", rmse_poly)
print("Polynomial R²:", r2_poly)
# Out:
# Polynomial RMSE: 0.9947619298981352
# Polynomial R²: 0.009649846444697352

# %%
y_poly_pred = poly_lr.predict(X_test_p)

rmse_poly = np.sqrt(mean_squared_error(y_test_p, y_poly_pred))
r2_poly = r2_score(y_test_p, y_poly_pred)

print("Polynomial RMSE:", rmse_poly)
print("Polynomial R²:", r2_poly)
# Out:
# Polynomial RMSE: 0.9947619298981352
# Polynomial R²: 0.009649846444697352

# %%
# Logistic Regression
median_hour = df['Hour'].median()
df['DayCrime'] = (df['Hour'] > median_hour).astype(int)
df['DayCrime'].value_counts()
X = df[['Year', 'Month', 'LATITUDE', 'LONGITUDE']]
y = df['DayCrime']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train, y_train)

y_log_pred = log_reg.predict(X_test)
